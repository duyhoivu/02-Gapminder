# %%
import glob, os
import pandas as pd

# %%
files = glob.glob("data/*.csv")
files
# Out:
# ['data\\gdp_per_capita.csv',
#  'data\\life_expectancy_years.csv',
#  'data\\population_total.csv']

# %%
d = {}

for file in files:
    d[file] = pd.read_csv(file)
    d[file].set_index("country", inplace=True)

# %%
labels = ['GDP per capita', 'Life Expectancy', "Total Population"]

# %%
d
# Out:
# {'data\\gdp_per_capita.csv':                       1800  1801  1802  1803  1804  1805  1806  1807  1808  \
#  country
#  Afghanistan            674   674   674   674   674   674   674   674   674
#  Angola                 691   693   697   700   702   705   709   712   716
#  Albania                746   746   746   746   746   747   747   747   747
#  Andorra               1340  1340  1340  1350  1350  1350  1350  1360  1360
#  United Arab Emirates  1120  1120  1120  1130  1130  1140  1140  1150  1150
#  ...                    ...   ...   ...   ...   ...   ...   ...   ...   ...
#  Samoa                 1570  1570  1570  1570  1570  1570  1570  1570  1570
#  Yemen                  981   983   986   988   992   994   997  1000  1000
#  South Africa          1760  1740  1720  1700  1680  1590  1590  1730  1510
#  Zambia                 741   743   746   747   749   750   752   755   756
#  Zimbabwe               972   973   974   975   976   977   978   979   981
#
# ...

# %%
for df in d:
    df.set_index("country",)
# Out:
#                   country  1800  1801  1802  1803  1804  1805  1806  1807  \
# 0             Afghanistan   674   674   674   674   674   674   674   674
# 1                  Angola   691   693   697   700   702   705   709   712
# 2                 Albania   746   746   746   746   746   747   747   747
# 3                 Andorra  1340  1340  1340  1350  1350  1350  1350  1360
# 4    United Arab Emirates  1120  1120  1120  1130  1130  1140  1140  1150
# ..                    ...   ...   ...   ...   ...   ...   ...   ...   ...
# 190                 Samoa  1570  1570  1570  1570  1570  1570  1570  1570
# 191                 Yemen   981   983   986   988   992   994   997  1000
# 192          South Africa  1760  1740  1720  1700  1680  1590  1590  1730
# 193                Zambia   741   743   746   747   749   750   752   755
# 194              Zimbabwe   972   973   974   975   976   977   978   979
#
#      1808  ...   2041   2042   2043   2044   2045   2046   2047   2048   2049  \
# ...
