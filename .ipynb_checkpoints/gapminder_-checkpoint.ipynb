# %%
import glob, os
import pandas as pd

# %%
files = glob.glob("data/*.csv")
files
# Out:
# ['data\\gdp_per_capita.csv',
#  'data\\life_expectancy_years.csv',
#  'data\\population_total.csv']

# %%
urls = {'Life Expectancy' : 'https://raw.githubusercontent.com/open-numbers/ddf--gapminder--life_expectancy/master/ddf--datapoints--life_expectancy_at_birth--by--geo--time.csv',
       'Total Population' : 'https://raw.githubusercontent.com/open-numbers/ddf--gapminder--population_historic/master/ddf--datapoints--population_total--by--geo--time.csv',
       'GDP Per Capita' : 'https://raw.githubusercontent.com/open-numbers/ddf--gapminder--gdp_per_capita_cppp/master/ddf--datapoints--income_per_person_gdppercapita_ppp_inflation_adjusted--by--geo--time.csv'}

# %%
urls.items()
# Out:
# dict_items([('Life Expectancy', 'https://raw.githubusercontent.com/open-numbers/ddf--gapminder--life_expectancy/master/ddf--datapoints--life_expectancy_at_birth--by--geo--time.csv'), ('Total Population', 'https://raw.githubusercontent.com/open-numbers/ddf--gapminder--population_historic/master/ddf--datapoints--population_total--by--geo--time.csv'), ('GDP Per Capita', 'https://raw.githubusercontent.com/open-numbers/ddf--gapminder--gdp_per_capita_cppp/master/ddf--datapoints--income_per_person_gdppercapita_ppp_inflation_adjusted--by--geo--time.csv')])

# %%
d = {}

for url in urls.items():
    d[url[0]] = pd.read_csv(url[1])
    d[url[0]].set_index(["time", "geo"], inplace=True)

# %%
d['Life Expectancy']
# Out:
#           life_expectancy_at_birth
# time geo
# 1800 afg                     28.21
# 1801 afg                     28.20
# 1802 afg                     28.19
# 1803 afg                     28.18
# 1804 afg                     28.17
# ...                            ...
# 2096 zwe                     73.91
# 2097 zwe                     74.04
# 2098 zwe                     74.17
# 2099 zwe                     74.30
# 2100 zwe                     74.43
#
# [56616 rows x 1 columns]

# %%
d['GDP Per Capita']
# Out:
#           income_per_person_gdppercapita_ppp_inflation_adjusted
# time geo
# 1800 afg                                                674
# 1801 afg                                                674
# 1802 afg                                                674
# 1803 afg                                                674
# 1804 afg                                                674
# ...                                                     ...
# 2046 zwe                                               3881
# 2047 zwe                                               3963
# 2048 zwe                                               4047
# 2049 zwe                                               4133
# 2050 zwe                                               4221
#
# [48945 rows x 1 columns]

# %%
d['Total Population']
# Out:
#           population_total
# time geo
# 1800 afg           3280000
# 1801 afg           3280000
# 1802 afg           3280000
# 1803 afg           3280000
# 1804 afg           3280000
# ...                    ...
# 2096 zwe          30940779
# 2097 zwe          30952208
# 2098 zwe          30959811
# 2099 zwe          30964052
# 2100 zwe          30965421
#
# [59297 rows x 1 columns]

# %%
pd.merge(d['Life Expectancy'], d['GDP Per Capita'], left_index=True, right_index=True)
# Out:
#           life_expectancy_at_birth  \
# time geo
# 1800 afg                     28.21
# 1801 afg                     28.20
# 1802 afg                     28.19
# 1803 afg                     28.18
# 1804 afg                     28.17
# ...                            ...
# 2046 zwe                     66.89
# 2047 zwe                     67.07
# 2048 zwe                     67.25
# 2049 zwe                     67.43
# 2050 zwe                     67.60
#
#           income_per_person_gdppercapita_ppp_inflation_adjusted
# time geo
# 1800 afg                                                674
# 1801 afg                                                674
# 1802 afg                                                674
# 1803 afg                                                674
# 1804 afg                                                674
# ...                                                     ...
# 2046 zwe                                               3881
# 2047 zwe                                               3963
# 2048 zwe                                               4047
# 2049 zwe                                               4133
# 2050 zwe                                               4221
#
# [47316 rows x 2 columns]

# %%
from functools import reduce

# %%
merged_df = reduce(lambda l, r: pd.merge(l, r, left_index=True, right_index=True), d.values())

# %%
country_info = pd.read_csv("https://raw.githubusercontent.com/open-numbers/ddf--gapminder--population_historic/master/ddf--entities--geo--country.csv")

# %%
country_info.head()
# Out:
#   country g77_and_oecd_countries        income_groups  is--country  \
# 0    abkh                 others                  NaN         True
# 1     abw                 others          high_income         True
# 2     afg                    g77           low_income         True
# 3     ago                    g77  lower_middle_income         True
# 4     aia                 others                  NaN         True
#
#   iso3166_1_alpha2 unicode_region_subtag iso3166_1_alpha3  iso3166_1_numeric  \
# 0              NaN                   NaN              NaN                NaN
# 1               AW                    AW              ABW              533.0
# 2               AF                    AF              AFG                4.0
# 3               AO                    AO              AGO               24.0
# 4               AI                    AI              AIA              660.0
#
#   iso3166_2  landlocked  ...         name  un_state world_4region  \
# 0       NaN         NaN  ...     Abkhazia     False        europe
# 1       NaN   coastline  ...        Aruba     False      americas
# 2       NaN  landlocked  ...  Afghanistan      True          asia
# 3       NaN   coastline  ...       Angola      True        africa
# 4       NaN   coastline  ...     Anguilla     False      americas
#
#          world_6region  unicef_region income_3groups  \
# 0  europe_central_asia            NaN            NaN
# 1              america            NaN    high_income
# 2           south_asia             sa     low_income
# 3   sub_saharan_africa            ssa  middle_income
# 4              america            NaN            NaN
#
#                         un_sdg_region              un_sdg_ldc  \
# 0                                 NaN                     NaN
# 1  un_latin_america_and_the_caribbean  un_not_least_developed
# 2        un_central_and_southern_asia      un_least_developed
# 3               un_sub_saharan_africa      un_least_developed
# 4  un_latin_america_and_the_caribbean  un_not_least_developed
#
#             unhcr_region west_and_rest
# 0                    NaN           NaN
# 1         unhcr_americas           NaN
# 2     unhcr_asia_pacific          rest
# 3  unhcr_southern_africa          rest
# 4         unhcr_americas           NaN
#
# [5 rows x 23 columns]

# %%
country_df = country_info[['country', 'iso3166_1_alpha3', 'name', 'world_4region']]

# %%
country_df = country_df.dropna()

# %%
country_df['iso3166_1_alpha3'] = country_df['iso3166_1_alpha3'].apply(lambda x: str(x).lower())

# %%
country_df.head()
# Out:
#   country iso3166_1_alpha3         name world_4region
# 1     abw              abw        Aruba      americas
# 2     afg              afg  Afghanistan          asia
# 3     ago              ago       Angola        africa
# 4     aia              aia     Anguilla      americas
# 6     ala              ala        Åland        europe

# %%
country_df.set_index("iso3166_1_alpha3", inplace = True)

# %%
country_df.index.names=['geo']

# %%
country_df.head()
# Out:
#     country         name world_4region
# geo
# abw     abw        Aruba      americas
# afg     afg  Afghanistan          asia
# ago     ago       Angola        africa
# aia     aia     Anguilla      americas
# ala     ala        Åland        europe

# %%
final_df = pd.merge(merged_df, country_df, left_index=True, right_index=True)

# %%
final_df.head()
# Out:
#           life_expectancy_at_birth  population_total  \
# time geo
# 1800 afg                     28.21           3280000
# 1801 afg                     28.20           3280000
# 1802 afg                     28.19           3280000
# 1803 afg                     28.18           3280000
# 1804 afg                     28.17           3280000
#
#           income_per_person_gdppercapita_ppp_inflation_adjusted country  \
# time geo
# 1800 afg                                                674         afg
# 1801 afg                                                674         afg
# 1802 afg                                                674         afg
# 1803 afg                                                674         afg
# 1804 afg                                                674         afg
#
#                  name world_4region
# time geo
# 1800 afg  Afghanistan          asia
# 1801 afg  Afghanistan          asia
# 1802 afg  Afghanistan          asia
# 1803 afg  Afghanistan          asia
# 1804 afg  Afghanistan          asia

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 47316 entries, (1800, 'afg') to (2050, 'zwe')
# Data columns (total 6 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   life_expectancy_at_birth                               47316 non-null  float64
#  1   population_total                                       47316 non-null  int64
#  2   income_per_person_gdppercapita_ppp_inflation_adjusted  47316 non-null  int64
#  3   country                                                47316 non-null  object
#  4   name                                                   47316 non-null  object
#  5   world_4region                                          47316 non-null  object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 2.4+ MB

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
final_df.loc[2020]
# Out:
#      life_expectancy_at_birth  population_total  \
# geo
# afg                     63.39          38928341
# alb                     77.90           2877800
# dza                     76.20          43851043
# ago                     65.20          32866268
# atg                     76.25             97928
# ..                        ...               ...
# ven                     75.10          28435943
# vnm                     74.51          97338583
# yem                     67.76          29825968
# zmb                     63.08          18383956
# zwe                     60.69          14862927
#
#      income_per_person_gdppercapita_ppp_inflation_adjusted
# geo
# afg                                               1918
# alb                                              13265
# dza                                              10624
# ago                                               6219
# atg                                              17859
# ..                                                 ...
# ven                                               5796
# vnm                                               8197
# yem                                               2419
# zmb                                               3250
# zwe                                               2560
#
# [186 rows x 3 columns]

# %%
final_df.loc[1800+1]
# Out:
#      life_expectancy_at_birth  population_total  \
# geo
# afg                     28.20           3280000
# alb                     35.40            401773
# dza                     28.82           2509126
# ago                     26.98           1567028
# atg                     33.54             37000
# ..                        ...               ...
# ven                     32.20            978177
# vnm                     32.00           4099892
# yem                     23.39           2593000
# zmb                     32.60            758402
# zwe                     33.70           1085814
#
#      income_per_person_gdppercapita_ppp_inflation_adjusted country  \
# geo
# afg                                                674         afg
# alb                                                746         alb
# dza                                                788         dza
# ago                                                693         ago
# atg                                                846         atg
# ..                                                 ...         ...
# ven                                               1228         ven
# vnm                                                966         vnm
# yem                                                983         yem
# zmb                                                743         zmb
# zwe                                                973         zwe
#
#                     name world_4region
# geo
# afg          Afghanistan          asia
# alb              Albania        europe
# dza              Algeria        africa
# ago               Angola        africa
# atg  Antigua and Barbuda      americas
# ..                   ...           ...
# ven            Venezuela      americas
# vnm              Vietnam          asia
# yem                Yemen          asia
# zmb               Zambia        africa
# zwe             Zimbabwe        africa
#
# [186 rows x 6 columns]

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(data = final_df.loc[2020], y = "life_expectancy_at_birth", x = "income_per_person_gdppercapita_ppp_inflation_adjusted", size = "population_total", sizes=(100,1000), hue = "world_4region")
# Out:
# <AxesSubplot:xlabel='income_per_person_gdppercapita_ppp_inflation_adjusted', ylabel='life_expectancy_at_birth'>

# %%
import matplotlib
import matplotlib.animation as animation

# %%
# %matplotlib notebook

# %%
Writer = animation.writers['ffmpeg']
writer = Writer(fps=1, metadata=dict(artist='Me'), bitrate=1800)

# %%
fig = plt.figure(figsize=(15,8))
# plt.xlim(final_df['income_per_person_gdppercapita_ppp_inflation_adjusted'].min(), final_df['income_per_person_gdppercapita_ppp_inflation_adjusted'].max())
# plt.ylim(final_df['life_expectancy_at_birth'].min(), final_df['life_expectancy_at_birth'].max())
plt.xlabel('GDP Per Capita',fontsize=20)
plt.ylabel('Life Expectancy at birth',fontsize=20)

def animate(i):
    data = final_df.loc[1950+i] #select data range
    p = sns.scatterplot(data = data, y = "life_expectancy_at_birth", x = "income_per_person_gdppercapita_ppp_inflation_adjusted", size = "population_total", sizes=(100,1000), hue = "world_4region")
    plt.setp(p.lines,linewidth=7)
    
ani = matplotlib.animation.FuncAnimation(fig, animate, frames=200, repeat=True)

# %%
ani.save("test.mp4")

# %%
import plotly_express as px

# %%
px.data.gapminder().head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %% [markdown]
# # Plotly express

# %%
plotly_df = final_df.reset_index()
plotly_df.head()
# Out:
#    time  geo  life_expectancy_at_birth  population_total  \
# 0  1800  afg                     28.21           3280000
# 1  1801  afg                     28.20           3280000
# 2  1802  afg                     28.19           3280000
# 3  1803  afg                     28.18           3280000
# 4  1804  afg                     28.17           3280000
#
#    income_per_person_gdppercapita_ppp_inflation_adjusted country         name  \
# 0                                                674         afg  Afghanistan
# 1                                                674         afg  Afghanistan
# 2                                                674         afg  Afghanistan
# 3                                                674         afg  Afghanistan
# 4                                                674         afg  Afghanistan
#
#   world_4region
# 0          asia
# 1          asia
# 2          asia
# 3          asia
# 4          asia

# %%
px.scatter(final_df, x="income_per_person_gdppercapita_ppp_inflation_adjusted", y="life_expectancy_at_birth", animation_frame="year", animation_group="country",
           size="population_total", color="country", hover_name="country", 
           log_x = True, 
           size_max=45, range_x=[100,100000], range_y=[25,90])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [214], in <cell line: 1>()
# ----> 1 px.scatter(final_df, x="income_per_person_gdppercapita_ppp_inflation_adjusted", y="life_expectancy_at_birth", animation_frame=final_df.index, animation_group="country",
#       2            size="population_total", color="country", hover_name="country",
#       3            log_x = True,
#       4            size_max=45, range_x=[100,100000], range_y=[25,90])
#
# File ~\anaconda3\lib\site-packages\plotly\express\_chart_types.py:66, in scatter(data_frame, x, y, color, symbol, size, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, orientation, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, symbol_sequence, symbol_map, opacity, size_max, marginal_x, marginal_y, trendline, trendline_options, trendline_color_override, trendline_scope, log_x, log_y, range_x, range_y, render_mode, title, template, width, height)
#      12 def scatter(
#      13     data_frame=None,
#      14     x=None,
#    (...)
#      60     height=None,
#      61 ):
#      62     """
#      63     In a scatter plot, each row of `data_frame` is represented by a symbol
#      64     mark in 2D space.
#      65     """
# ---> 66     return make_figure(args=locals(), constructor=go.Scatter)
#
# File ~\anaconda3\lib\site-packages\plotly\express\_core.py:1945, in make_figure(args, constructor, trace_patch, layout_patch)
#    1942 layout_patch = layout_patch or {}
#    1943 apply_default_cascade(args)
# -> 1945 args = build_dataframe(args, constructor)
#    1946 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    1947     args = process_dataframe_hierarchy(args)
#
# File ~\anaconda3\lib\site-packages\plotly\express\_core.py:1405, in build_dataframe(args, constructor)
#    1402     args["color"] = None
#    1403 # now that things have been prepped, we do the systematic rewriting of `args`
# -> 1405 df_output, wide_id_vars = process_args_into_dataframe(
#    1406     args, wide_mode, var_name, value_name
#    1407 )
#    1409 # now that `df_output` exists and `args` contains only references, we complete
#    1410 # the special-case and wide-mode handling by further rewriting args and/or mutating
#    1411 # df_output
#    1413 count_name = _escape_col_name(df_output, "count", [var_name, value_name])
#
# File ~\anaconda3\lib\site-packages\plotly\express\_core.py:1148, in process_args_into_dataframe(args, wide_mode, var_name, value_name)
#    1146 # Case of multiindex
#    1147 if isinstance(argument, pd.MultiIndex):
# -> 1148     raise TypeError(
#    1149         "Argument '%s' is a pandas MultiIndex. "
#    1150         "pandas MultiIndex is not supported by plotly express "
#    1151         "at the moment." % field
#    1152     )
#    1153 # ----------------- argument is a special value ----------------------
#    1154 if isinstance(argument, Constant) or isinstance(argument, Range):
#
# TypeError: Argument 'animation_frame' is a pandas MultiIndex. pandas MultiIndex is not supported by plotly express at the moment.
